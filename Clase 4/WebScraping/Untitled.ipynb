# %%
from urllib.request import Request, urlopen
from pyquery import PyQuery

# %%
url = 'https://www.google.com/search?q=resultados+mundial+qatar&rlz=1C1CHZN_esCO1020CO1020&oq=resultados+mund&aqs=chrome.0.0i3j69i57j0i131i433j0i131i433i512j0i3l6.3801j0j7&sourceid=chrome&ie=UTF-8#sie=lg;/m/0fp_8fm;2;/m/030q7;mt;fp;1;;;'

# %%
req = Request(url, None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
content = urlopen(req).read()
pq = PyQuery(content)

resultado = str(pq('span'))

# %%
resultado
# Out:
# '<span class="QIqI7">TODOS</span></td><td><a class="CsQyDc" href="/search?q=resultados+mundial+qatar&amp;rlz=1C1CHZN_esCO1020CO1020&amp;source=lnms&amp;tbm=nws&amp;sa=X&amp;ved=0ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQ_AUIBSgB">NOTICIAS</a></td><td><a class="CsQyDc" href="/search?q=resultados+mundial+qatar&amp;rlz=1C1CHZN_esCO1020CO1020&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQ_AUIBigC">IMÁGENES</a></td><td><a class="CsQyDc" href="/search?q=resultados+mundial+qatar&amp;rlz=1C1CHZN_esCO1020CO1020&amp;source=lnms&amp;tbm=vid&amp;sa=X&amp;ved=0ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQ_AUIBygD">VIDEOS</a></td></tr></tbody></table></div></div><div><div> <div> <div class="ezO2md"><div><div>  <span class="qXLe6d x3G5ab">  <span class="fYyStc">Copa Mundial de la FIFA Catar 2022™</span>  </span> </div><div class="YDG3ed FrIlee"><table class="qcqKgb"><tr><td/><td class="cHe4k">  <span class="qXLe6d FrIlee">  <span class="fYyStc pyMRrb">Entretiempo</span>  </span> </td></tr><tr><td>Argentina</td><td class="cHe4k">0</td></tr><tr><td>México</td><td class="cHe4k">0</td></tr></table></div><div class="aAhEM"/><div class="YDG3ed FrIlee"><table class="qcqKgb"><tr><td/><td class="cHe4k">  <span class="qXLe6d FrIlee">  <span class="fYyStc">Finalizado</span>  <span class="fYyStc">, </span>  <span class="fYyStc YVIcad">Hoy</span>  </span> </td></tr><tr><td>Francia</td><td class="cHe4k">2</td></tr><tr><td>Dinamarca</td><td class="cHe4k">1</td></tr></table></div><div class="aAhEM"/><div class="YDG3ed FrIlee"><table class="qcqKgb"><tr><td/><td class="cHe4k">  <span class="qXLe6d FrIlee">  <span class="fYyStc">Finalizado</span>  <span class="fYyStc">, </span>  <span class="fYyStc YVIcad">Hoy</span>  </span> </td></tr><tr><td>Polonia</td><td class="cHe4k">2</td></tr><tr><td>Arabia Saudita</td><td class="cHe4k">0</td></tr></table></div><div class="YDG3ed">  <span class="qXLe6d F9iS2e WMQ2Le">  <span class="fYyStc">Todos los horarios corresponden a la hora estándar de Colombia</span>  </span> </div></div></div> </div> </div><div> <div> <div class="ezO2md"><div><div>  <span class="qXLe6d x3G5ab">  <span class="dloBPe fYyStc">Noticias destacadas</span>  </span> </div><div><table class="VeHcBf"><tbody><tr><td><a class="ZWRArf" href="/url?q=https://www.marca.com/futbol/mundial/2022/11/26/6381bc0c45bbea00201f480e-directo.html&amp;sa=U&amp;ved=2ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQvOMEegQIChAC&amp;usg=AOvVaw3O3E2pqDjcpC_XasgFghdC"><span class="CVA68e qXLe6d">  <span class="qXLe6d FrIlee">  <span class="fYyStc M3vVJe">Mundial Qatar 2022, en directo | Partidos, resultados y última hora de la \nCopa del Mundo hoy en vivo</span>  </span> </span>  <span class="qXLe6d F9iS2e">  <span class="fYyStc dXDvrc">MARCA</span>  <span class="fYyStc"> · </span>  <span class="fYyStc YVIcad">hace 14 minutos</span>  </span> </a></td></tr></tbody></table></div><div><table class="VeHcBf"><tbody><tr><td><a class="ZWRArf" href="/url?q=https://cnnespanol.cnn.com/resultados-mundial-qatar-2022-grupos-tabla-posiciones-clasificacion/&amp;sa=U&amp;ved=2ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQvOMEegQIChAF&amp;usg=AOvVaw0kaj7cRDDQJjyOtQI_9gLf"><span class="CVA68e qXLe6d">  <span class="qXLe6d FrIlee">  <span class="fYyStc M3vVJe">Resultados del Mundial de Qatar 2022: grupos y clasificación en vivo</span>  </span> </span>  <span class="qXLe6d F9iS2e">  <span class="fYyStc dXDvrc">CNN</span>  <span class="fYyStc"> · </span>  <span class="fYyStc YVIcad">hace 1 día</span>  </span> </a></td></tr></tbody></table></div><div><table class="VeHcBf"><tbody><tr><td><a class="ZWRArf" href="/url?q=https://as.com/futbol/mundial/argentina-mexico-en-directo-mundial-de-qatar-2022-hoy-en-vivo-n/&amp;sa=U&amp;ved=2ahUKEwiXwKPE0sz7AhWhkZUCHSsjDXUQvOMEegQIChAI&amp;usg=AOvVaw2AIX51eE50BnB81HASQl6l"><span class="CVA68e qXLe6d">  <span class="qXLe6d FrIlee">  <span class="fYyStc M3vVJe">Argentina - México en vivo: Mundial de Qatar 2022 hoy, partido en directo</span>  </span> </span>  <span class="qXLe6d F9iS2 ...

# %% [markdown]
# ### INFORMACION DANE

# %%
url = 'https://www.dane.gov.co/index.php/indicadores-economicos'

# %%
req = Request(url, None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
content = urlopen(req).read()
pq = PyQuery(content)
trm = [i.text() for i in pq('table').eq(1)('h1').items()]
trm = float(trm[0].replace(".",'').replace("$",'').replace(",",'.'))

# %%
trm
# Out:
# 4875.91

# %%
5 * trm
# Out:
# 24379.55
